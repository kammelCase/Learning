# %%
import numpy as np
import pandas as pd

# this chapter in not in JDV's book, but feels important
# for writing clean and readable code!

# %%
spotify = pd.read_csv('data/spotify_songs.csv')
spotify.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
# spotify.dropna(inplace=True)
spotify.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %%
# lets grab some of these columns and narrow this down

cols = ['playlist_genre', 'track_id', 'track_name', 'track_popularity', 
        'danceability', 'energy', 'duration_ms']

spotify[cols].dtypes
# Out:
# track_id             object
# track_name           object
# track_popularity      int64
# danceability        float64
# energy              float64
# duration_ms           int64
# dtype: object

# %%
# let's look at some memory usage

spotify[cols].memory_usage(deep=True)
# Out:
# Index                   132
# track_id            2593807
# track_name          2480602
# track_popularity     262664
# danceability         262664
# energy               262664
# duration_ms          262664
# dtype: int64

# %%
# total mem usage

spotify[cols].memory_usage(deep=True).sum()
# Out:
# 6125197

# %%
# introducing chaining!

(spotify
    [cols]
    .select_dtypes(int)
    .describe()
)
# Out:
#        track_popularity    duration_ms
# count      32833.000000   32833.000000
# mean          42.477081  225799.811622
# std           24.984074   59834.006182
# min            0.000000    4000.000000
# 25%           24.000000  187819.000000
# 50%           45.000000  216000.000000
# 75%           62.000000  253585.000000
# max          100.000000  517810.000000

# %%
# does track_popularity need to be an int64? probably not...

# lets ask numpy what the ranges are for int8
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
(spotify
    [cols]                                  # select cols
    .astype({'track_popularity':'int8'})    # astype -> dict -> int8
    .select_dtypes('int')                # this is just to reselect by dtype
    .describe()                             # and to display some results here
)
# Out:
#          duration_ms
# count   32833.000000
# mean   225799.811622
# std     59834.006182
# min      4000.000000
# 25%    187819.000000
# 50%    216000.000000
# 75%    253585.000000
# max    517810.000000

# %%
# i think we can convert energy and danceability to a float32
# it won't save a ton of memory but it's something!

np.finfo(np.float32)
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)

# %%
# yeah, float32 should work

(spotify
    [cols]
    .select_dtypes(float)
    .describe()
    )
# Out:
#        danceability        energy
# count  32833.000000  32833.000000
# mean       0.654850      0.698619
# std        0.145085      0.180910
# min        0.000000      0.000175
# 25%        0.563000      0.581000
# 50%        0.672000      0.721000
# 75%        0.761000      0.840000
# max        0.983000      1.000000

# %%
(spotify
    [cols]
    .astype({'danceability':'float32', 'energy':'float32'})
    .select_dtypes(float)
    .describe()
)

# looks clean, and data looks identical
# Out:
#        danceability        energy
# count  32833.000000  32833.000000
# mean       0.654850      0.698619
# std        0.145086      0.180909
# min        0.000000      0.000175
# 25%        0.563000      0.581000
# 50%        0.672000      0.721000
# 75%        0.761000      0.840000
# max        0.983000      1.000000

# %%
spotify[cols].dtypes
# Out:
# track_id             object
# track_name           object
# track_popularity      int64
# danceability        float64
# energy              float64
# duration_ms           int64
# dtype: object

# %%
# searching for NaN
# found some

# %time spotify[spotify['track_name'].isnull()]
# Out:
# CPU times: user 858 µs, sys: 249 µs, total: 1.11 ms
# Wall time: 887 µs
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# 8151              HIP&HOP  5DyJsJZOpMJh34WvUrQzMV            rap  ...   6
# 9282          GANGSTA Rap  5GA8GDo7RQC3JEanT81B3g            rap  ...  11
# 9283          GANGSTA Rap  5GA8GDo7RQC3JEanT81B3g            rap  ...  10
# 19568  Reggaeton viejito🔥  0si5tw70PIgPkY1Eva6V8f          latin  ...  11
# 19811       latin hip hop  3nH8aytdqNeRbcRCg3dw9q          latin  ...   6
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 8151     -7.635     1       0.1760        0.0410           0.00000    0.1160
# 9282     -5.364     0       0.3190        0.0534           0.00000    0.5530
# 9283     -5.907     0       0.3070        0.0963           0.00000    0.0888
# 19568    -6.075     0       0.0366        0.0606           0.00653    0.1030
# 19811    -7.635     1       0.1760        0.0410           0.00000    0.1160
#
#        valence    tempo  duration_ms
# 8151     0.649   95.999       282707
# 9282     0.191  146.153       202235
# 9283     0.505   86.839       206465
# 19568    0.726   97.017       252773
# 19811    0.649   95.999       282707
#
# [5 rows x 23 columns]

# %%
# same deal, just curious which one is faster

# %time (spotify[cols].query('track_name.isna()'))
# Out:
# CPU times: user 2.17 ms, sys: 924 µs, total: 3.1 ms
# Wall time: 2.29 ms
#                      track_id track_name  track_popularity  danceability  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN                 0         0.714
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN                 0         0.678
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN                 0         0.465
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN                 0         0.675
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN                 0         0.714
#
#        energy  duration_ms
# 8151    0.821       282707
# 9282    0.659       202235
# 9283    0.820       206465
# 19568   0.919       252773
# 19811   0.821       282707

# %%
(spotify
    [cols]
    .assign(track_name=spotify.track_name.fillna('hello').astype('object'))
)
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name  track_popularity  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...                66
# 1                        Memories - Dillon Francis Remix                67
# 2                        All the Time - Don Diablo Remix                70
# 3                      Call You Mine - Keanu Silva Remix                60
# 4                Someone You Loved - Future Humans Remix                69
# ...                                                  ...               ...
# 32828               City Of Lights - Official Radio Edit                42
# 32829                Closer - Sultan & Ned Shepard Remix                20
# 32830                       Sweet Surrender - Radio Edit                14
# 32831                     Only For You - Maor Levi Remix                15
# 32832                             Typhoon - Original Mix                27
#
#        danceability  energy  duration_ms
# 0             0.748   0.916       194754
# 1             0.726   0.815       162600
# 2             0.675   0.931       176616
# 3             0.718   0.930       169093
# 4             0.650   0.833       189052
# ...             ...     ...          ...
# 32828         0.428   0.922       204375
# 32829         0.522   0.786       353120
# 32830         0.529   0.821       210112
# 32831         0.626   0.888       367432
# 32832         0.603   0.884       337500
#
# [32833 rows x 6 columns]

# %%
# this is really useful for finding if something is categorical or more "cardinal"
# in this case, it's obvs pretty categorical

(spotify
    ['playlist_genre']
    .value_counts(dropna=False)
    )
# Out:
# playlist_genre
# edm      6043
# rap      5746
# pop      5507
# r&b      5431
# latin    5155
# rock     4951
# Name: count, dtype: int64

# %%
spotify[cols].memory_usage(deep=True).sum()
# Out:
# 6125197

# %%
# we can convert this to a categorical type

(spotify
    [cols]
    .astype({'playlist_genre':'category'})
    # .memory_usage(deep=True)
    # .sum()
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/5x/1n063tsx6jx9wzcy34jzlqzh0000gn/T/ipykernel_43549/4042220804.py in ?()
#       1 # we can convert this to a categorical type
#       2
#       3 (spotify
#       4     [cols]
# ----> 5     .astype({'playlist_genre':'category'})
#       6     # .memory_usage(deep=True)
#       7     # .sum()
#       8     )
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype, copy, errors)
#    6286             dtype_ser = Series(dtype, dtype=object)
#    6287
#    6288             for col_name in dtype_ser.index:
#    6289                 if col_name not in self:
# -> 6290                     raise KeyError(
#    6291                         "Only a column name can be used for the "
#    6292                         "key in a dtype mappings argument. "
#    6293                         f"'{col_name}' not found in columns."
#
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'playlist_genre' not found in columns."
